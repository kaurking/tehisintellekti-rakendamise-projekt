# %%
import pandas as pd
df = pd.read_csv("toorandmed.csv")

pd.set_option("display.max_columns", None)

df.head()
# Out:
#                             course_uuid         code  \
# 0  eefb3a8d-7669-a5dc-9e13-6f95d719ebdf  LOMR.03.021
# 1  76162416-d608-f48f-ec5d-5c40ce9b320d  FLFI.00.016
# 2  fdffd50c-3d1b-3517-aaef-c0ea70fa85e0  FLGR.01.138
# 3  9c7f4c4c-f4a5-4a5d-533e-7a85e99babcf  LOKT.00.009
# 4  b9d5b558-bf74-62fc-bfd8-43618a81341d  LOKT.04.003
#
#                                        title__en  \
# 0  Practical Course of Microbiology and Virology
# 1                               Doctoral Seminar
# 2          History of English-Speaking Countries
# 3                              Medical Chemistry
# 4                Colloid and Surface Chemistry I
#
#                               version__title__en  credits  \
# 0  Practical Course of Microbiology and Virology      6.0
# 1                               Doctoral Seminar     15.0
# 2          History of English-Speaking Countries      6.0
# 3                              Medical Chemistry      5.0
# ...

# %%
list(df.columns)
# Out:
# ['course_uuid',
#  'code',
#  'title__en',
#  'version__title__en',
#  'credits',
#  'overview__description__en',
#  'version__overview__description__en',
#  'overview__learning_outcomes_text_en',
#  'uuid',
#  'state__code',
#  'state__et',
#  'state__en',
#  'last_update',
#  'title__et',
#  'general__input_languages',
#  'general__structural_unit_shares',
#  'general__type__code',
#  'general__type__et',
#  'general__type__en',
#  'general__structural_units',
#  'additional_info__duration_in_semesters',
#  'additional_info__assessment_scale__code',
#  'additional_info__assessment_scale__et',
#  'additional_info__assessment_scale__en',
#  'additional_info__is_vota_course',
#  'additional_info__is_continuous_learning_course',
#  'additional_info__prerequisites',
#  'overview__description__et',
#  'overview__objectives',
#  'overview__learning_outcomes',
#  '_actions__is_editable',
#  '_actions__is_version_creatable',
#  '_actions__is_deletable',
#  'overview__objectives_text_en',
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3031 entries, 0 to 3030
# Columns: 223 entries, course_uuid to version__overview__description__vro
# dtypes: bool(5), float64(23), int64(1), object(194)
# memory usage: 5.1+ MB

# %%
df.iloc[[306]]
# Out:
#                               course_uuid         code  \
# 306  48ba4107-f72d-e3f6-5804-1040423bf341  USUS.00.016
#
#                                 title__en  \
# 306  Sumerian Language and Writing System
#
#                        version__title__en  credits  \
# 306  Sumerian Language and Writing System      6.0
#
#                              overview__description__en  \
# 306  On the basis of this course the students will ...
#
#                     version__overview__description__en  \
# 306  On the basis of this course the students will ...
#
#                    overview__learning_outcomes_text_en  \
# 306  - The students will:\n- - know the grammatical...
#
#                                      uuid state__code   state__et  state__en  \
# 306  48ba4107-f72d-e3f6-5804-1040423bf341   confirmed  Kinnitatud  confirmed
#
#              last_update            title__et  \
# 306  2024-02-05T11:04:36  Sumeri keel ja kiri
#
# ...

# %%
list(df.iloc[306])
# Out:
# ['48ba4107-f72d-e3f6-5804-1040423bf341',
#  'USUS.00.016',
#  'Sumerian Language and Writing System',
#  'Sumerian Language and Writing System',
#  np.float64(6.0),
#  'On the basis of this course the students will learn the:\n- translating of Sumerian poetic texts;\n- analyzing their grammar, phonology, morphology and syntax;\n- dealing with some aspects of a textual critical analysis of appropriate poetic texts.',
#  'On the basis of this course the students will learn the:\n- translating of Sumerian poetic texts;\n- analyzing their grammar, phonology, morphology and syntax;\n- dealing with some aspects of a textual critical analysis of appropriate poetic texts.',
# ...
